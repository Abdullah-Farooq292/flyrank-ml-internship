# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah-Farooq292/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Abdullah-Farooq292/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# I'm choosing Lane 2: Refresh/Content Opportunity Scoring. This lane asks which pages should be reviewed first for refresh, expansion, or pruning. I chose it because in Week 1's notebooks, I already saw that a simple hand-written rule could rank pages reasonably well, but a trained model beat it — this lane builds directly on that idea by turning it into a ranked action list with clear reasons attached.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# This work improves the decision of which pages a content reviewer should check first, out of hundreds or thousands of pages, when their time is limited. A content team or reviewer would act on the ranked list — choosing to refresh, expand, or leave a page as-is based on its score and reason code. If the recommendation is wrong in one direction (flagging a healthy page as needing review), the cost is wasted reviewer time on a page that didn't need attention. If it's wrong in the other direction (missing a page that's actually declining), the cost is a lost opportunity to catch and fix a problem before it gets worse — potentially losing more traffic or visibility over time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# Out of roughly 30,000 pages, 16,262 (over half) are currently labeled as "down" (declining) — a large pool that makes prioritization worthwhile, since a reviewer clearly can't check every page. There's also a clear opportunity gap by position: pages at page_1 average 35.5% CTR, while pages in the "deep" tier average only 5.5% CTR — showing that position alone drives a large, predictable swing in click performance. These numbers suggest there's both a large enough pool of declining pages and a measurable, explainable pattern (position) to build a ranked review system around.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, subprocess

if not os.path.isdir("flyrank-ml-internship"):
    subprocess.run(["git", "clone", "--depth", "1",
                    "https://github.com/Abdullah-Farooq292/flyrank-ml-internship"], check=True)
os.chdir("flyrank-ml-internship")

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

visible = df[df["impressions_90d"] >= 100]

print(df["trend_direction"].value_counts())
print(visible.groupby("position_tier")["ctr"].mean().sort_values(ascending=False))
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
# position_tier
# page_1      0.354760
# top_3       0.334128
# striking    0.255782
# page_3_5    0.142359
# deep        0.055415
# Name: ctr, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# My work will describe patterns I observe in this anonymized dataset — for example, which pages show signs of decline alongside real traffic, or where a hand-written rule and a trained model agree or disagree. These are observed and directional findings, meant to support a human reviewer's decision, not replace it. My work will not prove that refreshing a flagged page will cause traffic to recover — that would require an actual experiment, which this data can't provide. It also will not make any claims about how Google's search ranking algorithm works; it only describes patterns in FlyRank's own anonymized data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
